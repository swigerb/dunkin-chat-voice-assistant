# %% [markdown]
# # Azure OpenAI and AI Search Pipeline for Menu Ingestion
#
# ## 1: Notebook Introduction
# This notebook demonstrates how to:
# 1. Configure Azure OpenAI and Azure AI Search services.
# 2. Prepare the JSON data for ingestion into Azure AI Search.
# 3. Upload the prepared data to Azure AI Search for hybrid semantic search capabilities.

# %% [markdown]
# ## 2: Install Required Packages
#
# ### Description
# This cell installs all the necessary packages required for the notebook.
# It ensures that all dependencies are met before proceeding with the rest of the notebook.

# %%
# %pip install azure-core azure-search-documents python-dotenv langchain-openai langchain-community openai pydantic tenacity pdf2image pytesseract
# Out:
# Requirement already satisfied: azure-core in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (1.36.0)
# Requirement already satisfied: azure-search-documents in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (11.6.0)
# Requirement already satisfied: python-dotenv in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (1.2.1)
# Requirement already satisfied: langchain-openai in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (1.1.0)
# Requirement already satisfied: langchain-community in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (0.4.1)
# Requirement already satisfied: openai in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (2.9.0)
# Requirement already satisfied: pydantic in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (2.12.5)
# Requirement already satisfied: tenacity in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (9.1.2)
# Requirement already satisfied: pdf2image in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (1.17.0)
# Requirement already satisfied: pytesseract in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (0.3.13)
# Requirement already satisfied: requests>=2.21.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from azure-core) (2.32.5)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from azure-core) (4.15.0)
# Requirement already satisfied: azure-common>=1.1 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from azure-search-documents) (1.1.28)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from azure-search-documents) (0.7.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-openai) (1.1.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from openai) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: idna>=2.8 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.4.54)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\brswig\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.25.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-community) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: pillow in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from pdf2image) (12.0.0)
# Requirement already satisfied: colorama in c:\users\brswig\appdata\roaming\python\python312\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 3: Imports and Environment Setup
#
# ### Description
# This cell imports necessary libraries and loads environment variables using `dotenv`.
# Ensure your `.env` file is properly set up with the required Azure API keys and endpoints.

# %%
# Import required libraries
from azure.core.credentials import AzureKeyCredential
from azure.core.exceptions import HttpResponseError
from azure.search.documents import SearchClient
from azure.search.documents.indexes import SearchIndexClient
from azure.search.documents.indexes.models import (
    SearchIndex,
    SimpleField,
    SearchField,
    SearchFieldDataType,
    VectorSearch,
    HnswAlgorithmConfiguration,
    VectorSearchProfile,
    AzureOpenAIVectorizer,
    AzureOpenAIVectorizerParameters,
    SemanticConfiguration,
    SemanticPrioritizedFields,
    SemanticField,
    SemanticSearch
)
from dotenv import load_dotenv
from langchain_community.vectorstores.azuresearch import AzureSearch
from langchain_openai import AzureOpenAIEmbeddings
from langchain_community.document_loaders import PyPDFLoader
from openai import AzureOpenAI
from pydantic import BaseModel
from tenacity import retry, stop_after_attempt, wait_exponential
from typing import List

import base64
import json
import os
import openai
import re

# Load environment variables from the repo's backend .env (fallback to current dir)
env_path = os.path.join("..", "app", "backend", ".env")
load_dotenv(dotenv_path=env_path)
load_dotenv()  # allows overriding with local .env if present
print(f"Loaded env file at {env_path}: {os.path.exists(env_path)}")
# Out:
# Loaded env file at ..\app\backend\.env: True

# %% [markdown]
# ## 4: Azure OpenAI and Azure AI Search Configuration
#
# ### Description
# This cell sets up the Azure OpenAI and AI Search configurations, including the embeddings and vector store.
# Ensure that the endpoints, API keys, and deployment names in the `.env` file match your Azure resource setup.

# %%
# Quick credential sanity check (prints masked values)
def _mask(val: str):
    if not val:
        return "<missing>"
    return f"len={len(val)}, suffix={val[-4:]}"

vars_to_check = {
    "AZURE_OPENAI_EASTUS_ENDPOINT": os.getenv("AZURE_OPENAI_EASTUS_ENDPOINT"),
    "AZURE_OPENAI_EASTUS_API_KEY": os.getenv("AZURE_OPENAI_EASTUS_API_KEY") or os.getenv("AZURE_OPENAI_API_KEY"),
    "AZURE_OPENAI_API_VERSION": os.getenv("AZURE_OPENAI_API_VERSION"),
    "AZURE_OPENAI_EMBEDDING_DEPLOYMENT": os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT"),
    "AZURE_SEARCH_ENDPOINT": os.getenv("AZURE_SEARCH_ENDPOINT"),
    "AZURE_SEARCH_API_KEY": os.getenv("AZURE_SEARCH_API_KEY"),
    "AZURE_SEARCH_INDEX": os.getenv("AZURE_SEARCH_INDEX"),
}

# Normalize to expected variable if only generic name is present
if not os.getenv("AZURE_OPENAI_EASTUS_API_KEY") and os.getenv("AZURE_OPENAI_API_KEY"):
    os.environ["AZURE_OPENAI_EASTUS_API_KEY"] = os.getenv("AZURE_OPENAI_API_KEY")

for name, value in vars_to_check.items():
    print(f"{name}: {_mask(value)}")

missing = [k for k, v in vars_to_check.items() if not v]
if missing:
    raise RuntimeError(f"Missing required environment variables: {', '.join(missing)}")
else:
    print("All required environment variables are present.")
# Out:
# AZURE_OPENAI_EASTUS_ENDPOINT: len=51, suffix=com/
# AZURE_OPENAI_EASTUS_API_KEY: len=32, suffix=3a90
# AZURE_OPENAI_API_VERSION: len=18, suffix=view
# AZURE_OPENAI_EMBEDDING_DEPLOYMENT: len=22, suffix=arge
# AZURE_SEARCH_ENDPOINT: len=65, suffix=.net
# AZURE_SEARCH_API_KEY: len=52, suffix=ZM0d
# AZURE_SEARCH_INDEX: len=11, suffix=chat
# All required environment variables are present.

# %%
# Azure OpenAI setup
aoai_eastus_endpoint = os.getenv("AZURE_OPENAI_EASTUS_ENDPOINT")
aoai_eastus_api_key = os.getenv("AZURE_OPENAI_EASTUS_API_KEY")
aoai_gpt4o_deployment = os.getenv("AZURE_OPENAI_GPT4O_DEPLOYMENT")
aoai_gpt4o_mini_deployment = os.getenv("AZURE_OPENAI_GPT4O_MINI_DEPLOYMENT")
aoai_openai_api_version = os.getenv("AZURE_OPENAI_API_VERSION")
aoai_embedding_deployment = os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT")

# Initialize the Azure OpenAI client
aoai_client = AzureOpenAI(
    azure_endpoint=aoai_eastus_endpoint,
    api_version=aoai_openai_api_version,
    api_key=aoai_eastus_api_key,
)

# Azure AI Search credentials
search_service_endpoint = os.getenv("AZURE_SEARCH_ENDPOINT")
search_api_key = os.getenv("AZURE_SEARCH_API_KEY")
index_name = os.getenv("AZURE_SEARCH_INDEX")
search_client = SearchClient(endpoint=search_service_endpoint, index_name=index_name, credential=AzureKeyCredential(search_api_key))
search_index_client = SearchIndexClient(endpoint=search_service_endpoint, index_name=index_name, credential=AzureKeyCredential(search_api_key))

print("Azure OpenAI and Azure Search clients initialized successfully.")
# Out:
# Azure OpenAI and Azure Search clients initialized successfully.

# %% [markdown]
# ## 5: Define and Create/Update Index Schema with Semantic Configuration
#
# ### Description
# This cell defines the schema for the Azure AI Search index, including fields for semantic search and vector search capabilities. It also includes logic to delete the existing index if it exists and create or update the index schema with the new configuration.

# %% [markdown]
# ### Note on enabling semantic ranker
#
# Semantic search is a service-level capability. If you see errors like "semantic search is not enabled," ensure the service has semantic ranker turned on (Standard tier or higher). You can enable it via CLI if the portal UI does not surface a toggle:
#
# `az search service update --name <service> --resource-group <rg> --semantic-search standard`
#
# Once enabled, the existing index schema here (with `semantic_search` and `menuSemanticConfig`) works without further changes.

# %%
# Define and Create/Update Index Schema with Semantic Configuration
if not index_name:
    raise RuntimeError("AZURE_SEARCH_INDEX is not set. Please set it in your .env and rerun the env/credential cells.")

index_schema = SearchIndex(
    name=index_name,
    fields=[
        # Unique identifier for each menu item
        SimpleField(name="id", type=SearchFieldDataType.String, key=True, sortable=True, filterable=True),
        
        # Fields for semantic search
        SearchField(name="category", type=SearchFieldDataType.String, sortable=True, filterable=True, facetable=True),
        SearchField(name="name", type=SearchFieldDataType.String, sortable=True, filterable=True, facetable=True),
        SearchField(name="description", type=SearchFieldDataType.String),
        SearchField(name="longDescription", type=SearchFieldDataType.String),  # Added long description
        SearchField(name="origin", type=SearchFieldDataType.String, filterable=True, facetable=True),
        SearchField(name="caffeineContent", type=SearchFieldDataType.String, filterable=True),  # Treat as string for now
        SearchField(name="brewingMethod", type=SearchFieldDataType.String, filterable=True),
        SearchField(name="popularity", type=SearchFieldDataType.String, filterable=True, facetable=True),
        
        # Sizes as JSON object
        SearchField(name="sizes", type=SearchFieldDataType.String, filterable=False, facetable=False),

        # Embedding field for vector search
        SearchField(
            name="embedding", 
            type=SearchFieldDataType.Collection(SearchFieldDataType.Single), 
            vector_search_dimensions=3072,  # Adjusted for most OpenAI embedding models
            vector_search_profile_name="menuHnswProfile"
        )
    ],
    vector_search=VectorSearch(
        algorithms=[
            HnswAlgorithmConfiguration(
                name="menuHnsw",
                kind="hnsw",
                parameters={
                    "m": 10,  # Adjusted for accuracy/memory trade-off
                    "efConstruction": 200  # Ensures recall during indexing
                }
            )
        ],
        profiles=[
            VectorSearchProfile(
                name="menuHnswProfile",
                algorithm_configuration_name="menuHnsw",
                vectorizer_name="menuVectorizer"
            )
        ],
        vectorizers=[
            AzureOpenAIVectorizer(
                vectorizer_name="menuVectorizer",
                parameters=AzureOpenAIVectorizerParameters(
                    resource_url=aoai_eastus_endpoint,
                    deployment_name=aoai_embedding_deployment,
                    model_name=aoai_embedding_deployment,
                    api_key=aoai_eastus_api_key
                )
            )
        ]
    ),
    semantic_search=SemanticSearch(
        configurations=[
            SemanticConfiguration(
                name="menuSemanticConfig",
                prioritized_fields=SemanticPrioritizedFields(
                    title_field=SemanticField(field_name="name"),  # Prioritize the "name" (e.g., "Espresso")
                    content_fields=[
                        SemanticField(field_name="description"),  # Primary content field
                        SemanticField(field_name="longDescription"),  # Provide detailed context
                        SemanticField(field_name="category")  # Assist in grouping similar items
                    ]
                )
            )
        ]
    ),
)

# Delete the existing index if it exists
try:
    search_index_client.delete_index(index_name)
    print(f"Deleted existing index: {index_name}")
except Exception as e:
    print(f"Index {index_name} does not exist or could not be deleted: {e}")

# Create or update the index schema
try:
    search_index_client.create_or_update_index(index=index_schema)
    print(f"Created index: {index_name}")
except Exception as e:
    raise RuntimeError(f"Failed to create/update index {index_name}: {e}")

# Verify index exists
existing = [i.name for i in search_index_client.list_indexes()]
print(f"Indexes present: {existing}")
if index_name not in existing:
    raise RuntimeError(f"Index {index_name} was not found after creation. Check endpoint/key and try again.")
# Out:
# Deleted existing index: coffee-chat
# Created index: coffee-chat
# Created index: coffee-chat
# Indexes present: ['coffee-chat']
# Indexes present: ['coffee-chat']

# %% [markdown]
# ## 6: Load and Process Menu Data
#
# ### Description
# This cell reads the `menuItems.json` file, processes the data to ensure all fields are populated, and prints the structured JSON data.

# %%
# Define candidate paths to the menuItems.json file
menu_items_candidates = [
    os.path.join('..', 'app', 'frontend', 'src', 'data', 'menuItems.json'),
    os.path.join('..', 'frontend', 'src', 'data', 'menuItems.json'),
]

menu_items_path = None
for candidate in menu_items_candidates:
    if os.path.exists(candidate):
        menu_items_path = candidate
        break

if not menu_items_path:
    raise FileNotFoundError(f"Could not find menuItems.json. Tried: {menu_items_candidates}")

print(f"Using menuItems.json at: {menu_items_path}")

# Read the JSON file
with open(menu_items_path, 'r') as file:
    menu_items = json.load(file)

# Build JSON with all fields, put empty string if not applicable
structured_menu_items = {"menuItems": []}

for category in menu_items['menuItems']:
    category_dict = {"category": category['category'], "items": []}
    for item in category['items']:
        item_dict = {
            "name": item['name'],
            "description": item.get('description', ''),
            "longDescription": item.get('longDescription', ''),
            "origin": item.get('origin', ''),
            "caffeineContent": item.get('caffeineContent', ''),
            "brewingMethod": item.get('brewingMethod', ''),
            "popularity": item.get('popularity', ''),
            "sizes": [{"size": size['size'], "price": size['price']} for size in item.get('sizes', [])]
        }
        category_dict["items"].append(item_dict)
    structured_menu_items["menuItems"].append(category_dict)

print(json.dumps(structured_menu_items, indent=2))
# Out:
# Using menuItems.json at: ..\app\frontend\src\data\menuItems.json
# {
#   "menuItems": [
#     {
#       "category": "Signature Lattes",
#       "items": [
#         {
#           "name": "Caramel Craze Latte",
#           "description": "Espresso with caramel drizzle and whipped cream",
#           "longDescription": "A Dunkin signature latte layered with bold espresso, caramel-flavored swirl, and steamed milk, topped with whipped cream and caramel drizzle for an indulgent finish.",
#           "origin": "Dunkin U.S. Menu",
#           "caffeineContent": "166 mg (medium)",
#           "brewingMethod": "Espresso machine",
#           "popularity": "Guest Favorite",
#           "sizes": [
#             {
#               "size": "small",
#               "price": 4.49
#             },
#             {
#               "size": "medium",
#               "price": 4.99
#             },
#             {
#               "size": "large",
#               "price": 5.49
#             }
#           ]
#         },
#         {
#           "name": "Cocoa Mocha Latte",
#           "description": "Chocolate-forward espresso drink finished with mocha drizzle",
#           "longDescription": "Balanced espresso, mocha swirl, and steamed milk create a smooth chocolate latte crowned with whipped cream and cocoa powder for an elevated Dunkin moment.",
#           "origin": "Inspire Brands Innovation Lab",
#           "caffeineContent": "170 mg (medium)",
#           "brewingMethod": "Espresso machine",
#           "popularity": "Seasonal Spotlight",
#           "sizes": [
#             {
#               "size": "small",
#               "price": 4.59
#             },
#             {
#               "size": "medium",
#               "price": 5.09
#             },
#             {
#               "size": "large",
#               "price": 5.59
#             }
#           ]
#         },
#         {
#           "name": "Toasted Almond Cold Foam Latte",
#           "description": "Iced latte with toasted almond swirl and cold foam cap",
#           "longDescription": "Chilled espresso poured over ice with toasted almond flavor, finished with vanilla cold foam for layered texture and sweetness.",
#           "origin": "Dunkin Next-Gen Restaurant",
#           "caffeineContent": "187 mg (medium)",
#           "brewingMethod": "Espresso over ice",
#           "popularity": "Emerging Favorite",
#           "sizes": [
#             {
#               "size": "small",
#               "price": 4.79
#             },
#             {
#               "size": "medium",
#               "price": 5.29
#             },
#             {
#               "size": "large",
#               "price": 5.79
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "category": "Cold Beverages",
#       "items": [
#         {
#           "name": "Original Cold Brew",
#           "description": "12-hour steeped cold brew over ice",
#           "longDescription": "Smooth, full-bodied cold brew handcrafted daily and served over ice. Add cold foam or a flavor swirl for a personalized sip.",
#           "origin": "Dunkin Breweries",
#           "caffeineContent": "260 mg (medium)",
#           "brewingMethod": "Cold steep",
#           "popularity": "High",
#           "sizes": [
#             {
#               "size": "small",
#               "price": 3.79
#             },
#             {
#               "size": "medium",
#               "price": 4.29
#             },
#             {
#               "size": "large",
#               "price": 4.79
#             }
#           ]
#         },
#         {
#           "name": "Strawberry Dragonfruit Refresher",
#           "description": "Green tea-based refresher with B vitamins",
#           "longDescription": "Vibrant strawberry dragonfruit flavor balanced with green tea and B vitamins for a light, energizing beverage without dairy.",
#           "origin": "Dunkin Beverage Innovation",
#           "caffeineContent": "99 mg (medium)",
#           "brewingMethod": "Green tea infusion",
#           "popularity": "Always On Menu",
#           "sizes": [
#             {
#               "size": "small",
#               "price": 3.29
#             },
#             {
#               "size": "medium",
#               "price": 3.79
#             },
#             {
#               "size": "large",
#               "price": 4.29
#             }
#           ]
#         },
#         {
#           "name": "Brown Sugar Cream Cold Brew",
#           "description": "Cold brew with brown sugar syrup and cinnamon-sugar cold foam",
#           "longDescription": "Slow-steeped cold brew sweetened with brown sugar syrup, topped with cinnamon-sugar dusted cold foam for a layered finish.",
#           "origin": "Inspire Brands Test Kitchen",
#           "caffeineContent": "267 mg (medium)",
#           "brewingMethod": "Cold steep",
#           "popularity": "Limited Time Feature",
#           "sizes": [
#             {
#               "size": "small",
#               "price": 4.29
#             },
#             {
#               "size": "medium",
#               "price": 4.79
#             },
#             {
#               "size": "large",
#               "price": 5.29
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "category": "Donuts & Bakery",
#       "items": [
#         {
#           "name": "Glazed Donut",
#           "description": "Classic yeast donut coated in vanilla glaze",
#           "longDescription": "Soft, airy donut finished with a signature sweet glaze. Pair it with hot coffee for the quintessential Dunkin duo.",
#           "origin": "Dunkin Bakery",
#           "caffeineContent": "",
#           "brewingMethod": "",
#           "popularity": "Iconic",
#           "sizes": [
#             {
#               "size": "standard",
#               "price": 1.49
#             }
#           ]
#         },
#         {
#           "name": "Boston Kreme Donut",
#           "description": "Custard-filled donut topped with chocolate icing",
#           "longDescription": "A nod to Dunkin's New England roots featuring silky Bavarian cream and rich chocolate icing.",
#           "origin": "Boston, MA",
#           "caffeineContent": "",
#           "brewingMethod": "",
#           "popularity": "Regional Favorite",
#           "sizes": [
#             {
#               "size": "standard",
#               "price": 1.79
#             }
#           ]
#         },
#         {
#           "name": "Everything Bagel & Cream Cheese",
#           "description": "Toasted everything bagel with plain cream cheese",
#           "longDescription": "Freshly toasted bagel coated with sesame, poppy seeds, garlic, and onion, served with cool cream cheese spread.",
#           "origin": "Dunkin Bakery",
#           "caffeineContent": "",
#           "brewingMethod": "",
#           "popularity": "Morning Rush MVP",
#           "sizes": [
#             {
#               "size": "standard",
#               "price": 3.29
#             }
#           ]
#         },
#         {
#           "name": "MUNCHKINS\u00c2\u00ae Donut Hole Treats (10 ct)",
#           "description": "Assorted bite-sized donuts",
#           "longDescription": "Shareable assortment of glazed, chocolate, and jelly MUNCHKINS donut holes\u00e2\u20ac\u201dperfect for offices and carpool lines.",
#           "origin": "Dunkin Bakery",
#           "caffeineContent": "",
#           "brewingMethod": "",
#           "popularity": "Group Favorite",
#           "sizes": [
#             {
#               "size": "standard",
#               "price": 3.99
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "category": "Breakfast Sandwiches",
#       "items": [
#         {
#           "name": "Bacon Egg & Cheese on Croissant",
#           "description": "Cherrywood smoked bacon, eggs, and American cheese",
#           "longDescription": "A flaky croissant stacked with cherrywood smoked bacon, fluffy eggs, and melty cheese to fuel busy mornings.",
#           "origin": "Dunkin Kitchens",
#           "caffeineContent": "",
#           "brewingMethod": "",
#           "popularity": "Top Seller",
#           "sizes": [
#             {
#               "size": "standard",
#               "price": 4.99
#             }
#           ]
#         },
#         {
#           "name": "Power Breakfast Sandwich",
#           "description": "Multi-grain bread with turkey sausage and egg whites",
#           "longDescription": "Better-for-you build with veggie egg white omelet, turkey sausage, and aged white cheddar on seeded multigrain bread.",
#           "origin": "Inspire Brands Nutrition Lab",
#           "caffeineContent": "",
#           "brewingMethod": "",
#           "popularity": "Balanced Choice",
#           "sizes": [
#             {
#               "size": "standard",
#               "price": 5.49
#             }
#           ]
#         },
#         {
#           "name": "Turkey Sausage Wake-Up Wrap",
#           "description": "Egg and turkey sausage in a warm tortilla",
#           "longDescription": "Portable protein with scrambled egg, turkey sausage, and American cheese inside a grilled tortilla.",
#           "origin": "Dunkin Anytime Menu",
#           "caffeineContent": "",
#           "brewingMethod": "",
#           "popularity": "Value Leader",
#           "sizes": [
#             {
#               "size": "standard",
#               "price": 2.59
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "category": "Extras",
#       "items": [
#         {
#           "name": "Flavor Swirl Add-On",
#           "description": "Caramel, mocha, French vanilla, or seasonal swirl",
#           "longDescription": "Rich, creamy swirls that add sweetness and color to any hot or iced beverage.",
#           "origin": "",
#           "caffeineContent": "",
#           "brewingMethod": "",
#           "popularity": "",
#           "sizes": [
#             {
#               "size": "standard",
#               "price": 0.75
#             }
#           ]
#         },
#         {
#           "name": "Whipped Cream",
#           "description": "Add whipped cream topping",
#           "longDescription": "Finish drinks with house-made whipped cream for extra texture and presentation.",
#           "origin": "",
#           "caffeineContent": "",
#           "brewingMethod": "",
#           "popularity": "",
#           "sizes": [
#             {
#               "size": "standard",
#               "price": 0.5
#             }
#           ]
#         },
#         {
#           "name": "Extra Espresso Shot",
#           "description": "Add one additional espresso shot",
#           "longDescription": "Boost any beverage with a fresh-pulled Dunkin espresso shot for added intensity.",
#           "origin": "",
#           "caffeineContent": "75 mg per shot",
#           "brewingMethod": "",
#           "popularity": "",
#           "sizes": [
#             {
#               "size": "standard",
#               "price": 1.0
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ## 7: Data Preparation and Embedding Generation
#
# ### Description
# This cell defines functions to sanitize document keys, generate embeddings using Azure OpenAI, and prepare the structured JSON data for ingestion into Azure AI Search. It includes retry logic for embedding generation and assigns embeddings to each document.

# %%
def sanitize_key(key):
    """Sanitize the document key to contain only valid characters."""
    return re.sub(r'[^a-zA-Z0-9_\-]', '_', key)

@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=5, max=60))
def generate_embeddings(texts):
    """
    Generate embeddings using Azure OpenAI with retry logic for a batch of texts.
    """
    response = aoai_client.embeddings.create(input=texts, model=aoai_embedding_deployment)
    return [res.embedding for res in response.data]

def prepare_data_for_azure_search(menu_items_data):
    """Transform parsed data for ingestion into Azure AI Search."""
    azure_search_documents = []
    menu_items = menu_items_data["menuItems"]  # Extract the list of categories
    texts_for_embedding = []
    document_keys = []

    for category in menu_items:
        for item in category["items"]:
            # Combine relevant fields for embedding
            combined_text = f"{category['category']} {item['name']} {item['description']} {item.get('longDescription', '')}"
            document_key = sanitize_key(f"{category['category']}_{item['name'].replace(' ', '_')}".lower())
            
            # Collect texts and keys for batch embedding
            texts_for_embedding.append(combined_text)
            document_keys.append(document_key)
            
            # Add the document to Azure Search format without embedding
            azure_search_documents.append({
                "id": document_key,  # Use sanitized document key
                "category": category["category"],
                "name": item["name"],
                "description": item["description"],
                "longDescription": item.get("longDescription", ""),  # Include long description if available
                "origin": item.get("origin", ""),  # Include origin if available
                "caffeineContent": item.get("caffeineContent", ""),  # Include caffeine content if available
                "brewingMethod": item.get("brewingMethod", ""),  # Include brewing method if available
                "popularity": item.get("popularity", ""),  # Include popularity if available
                "sizes": json.dumps(item["sizes"]),  # Convert sizes to JSON string
            })

    # Generate embeddings in batch
    embeddings = generate_embeddings(texts_for_embedding)

    # Assign embeddings to documents
    for i, embedding in enumerate(embeddings):
        azure_search_documents[i]["embedding"] = embedding

    return azure_search_documents

# Example usage
documents_for_index = prepare_data_for_azure_search(structured_menu_items)

for doc in documents_for_index:
    print(f"ID: {doc['id']}")
    print(f"Category: {doc['category']}")
    print(f"Name: {doc['name']}")
    print(f"Description: {doc['description']}")
    print(f"Long Description: {doc['longDescription']}")
    print(f"Origin: {doc['origin']}")
    print(f"Caffeine Content: {doc['caffeineContent']}")
    print(f"Brewing Method: {doc['brewingMethod']}")
    print(f"Popularity: {doc['popularity']}")
    print(f"Sizes: {doc['sizes']}")
    print(f"Embedding: {doc['embedding'][:10]}...")  # Print the first 10 dimensions for brevity
    print()  # Add a blank line between documents
# Out:
# ID: signature_lattes_caramel_craze_latte
# Category: Signature Lattes
# Name: Caramel Craze Latte
# Description: Espresso with caramel drizzle and whipped cream
# Long Description: A Dunkin signature latte layered with bold espresso, caramel-flavored swirl, and steamed milk, topped with whipped cream and caramel drizzle for an indulgent finish.
# Origin: Dunkin U.S. Menu
# Caffeine Content: 166 mg (medium)
# Brewing Method: Espresso machine
# Popularity: Guest Favorite
# Sizes: [{"size": "small", "price": 4.49}, {"size": "medium", "price": 4.99}, {"size": "large", "price": 5.49}]
# Embedding: [-0.03891349583864212, -0.03796124830842018, -0.028335819020867348, 0.037266362458467484, -0.013395817019045353, 0.0029870355501770973, 0.0047483728267252445, -0.013292870484292507, -0.02776961773633957, 0.019894268363714218]...
#
# ID: signature_lattes_cocoa_mocha_latte
# Category: Signature Lattes
# Name: Cocoa Mocha Latte
# Description: Chocolate-forward espresso drink finished with mocha drizzle
# Long Description: Balanced espresso, mocha swirl, and steamed milk create a smooth chocolate latte crowned with whipped cream and cocoa powder for an elevated Dunkin moment.
# Origin: Inspire Brands Innovation Lab
# Caffeine Content: 170 mg (medium)
# Brewing Method: Espresso machine
# Popularity: Seasonal Spotlight
# Sizes: [{"size": "small", "price": 4.59}, {"size": "medium", "price": 5.09}, {"size": "large", "price": 5.59}]
# Embedding: [-0.004301098641008139, -0.04092345014214516, -0.025632092729210854, 0.04454270750284195, -0.016713209450244904, 0.011672102846205235, 0.0010930477874353528, -0.005451505072414875, -0.011420046910643578, 0.01755339466035366]...
#
# ID: signature_lattes_toasted_almond_cold_foam_latte
# Category: Signature Lattes
# Name: Toasted Almond Cold Foam Latte
# Description: Iced latte with toasted almond swirl and cold foam cap
# Long Description: Chilled espresso poured over ice with toasted almond flavor, finished with vanilla cold foam for layered texture and sweetness.
# Origin: Dunkin Next-Gen Restaurant
# Caffeine Content: 187 mg (medium)
# Brewing Method: Espresso over ice
# Popularity: Emerging Favorite
# Sizes: [{"size": "small", "price": 4.79}, {"size": "medium", "price": 5.29}, {"size": "large", "price": 5.79}]
# Embedding: [-0.03742895647883415, -0.033622171729803085, -0.02984200417995453, 0.04256678372621536, -0.02840447798371315, -0.014135686680674553, -0.011300562880933285, -0.008239162154495716, -0.029921866953372955, 0.0076934341341257095]...
#
# ID: cold_beverages_original_cold_brew
# Category: Cold Beverages
# Name: Original Cold Brew
# Description: 12-hour steeped cold brew over ice
# Long Description: Smooth, full-bodied cold brew handcrafted daily and served over ice. Add cold foam or a flavor swirl for a personalized sip.
# Origin: Dunkin Breweries
# Caffeine Content: 260 mg (medium)
# Brewing Method: Cold steep
# Popularity: High
# Sizes: [{"size": "small", "price": 3.79}, {"size": "medium", "price": 4.29}, {"size": "large", "price": 4.79}]
# Embedding: [-0.008904076181352139, -0.04403161257505417, -0.014131767675280571, 0.00011610451474552974, -0.05326861888170242, -0.02518925629556179, -0.02295084111392498, 0.0067117041908204556, -0.03674967959523201, 0.013926343992352486]...
#
# ID: cold_beverages_strawberry_dragonfruit_refresher
# Category: Cold Beverages
# Name: Strawberry Dragonfruit Refresher
# Description: Green tea-based refresher with B vitamins
# Long Description: Vibrant strawberry dragonfruit flavor balanced with green tea and B vitamins for a light, energizing beverage without dairy.
# Origin: Dunkin Beverage Innovation
# Caffeine Content: 99 mg (medium)
# Brewing Method: Green tea infusion
# Popularity: Always On Menu
# Sizes: [{"size": "small", "price": 3.29}, {"size": "medium", "price": 3.79}, {"size": "large", "price": 4.29}]
# Embedding: [-0.0010708029149100184, -0.01672048680484295, -0.002434247639030218, 0.03272267058491707, 0.006574463564902544, -0.013767465949058533, 0.020897284150123596, -0.03333456069231033, -0.044774193316698074, -0.009810150600969791]...
#
# ID: cold_beverages_brown_sugar_cream_cold_brew
# Category: Cold Beverages
# Name: Brown Sugar Cream Cold Brew
# Description: Cold brew with brown sugar syrup and cinnamon-sugar cold foam
# Long Description: Slow-steeped cold brew sweetened with brown sugar syrup, topped with cinnamon-sugar dusted cold foam for a layered finish.
# Origin: Inspire Brands Test Kitchen
# Caffeine Content: 267 mg (medium)
# Brewing Method: Cold steep
# Popularity: Limited Time Feature
# Sizes: [{"size": "small", "price": 4.29}, {"size": "medium", "price": 4.79}, {"size": "large", "price": 5.29}]
# Embedding: [0.0099182715639472, -0.019795643165707588, -0.017191670835018158, 0.03228380158543587, -0.0017808579141274095, -0.004815985448658466, -0.014914898201823235, -0.0198365431278944, -0.048725638538599014, 0.027348525822162628]...
#
# ID: donuts___bakery_glazed_donut
# Category: Donuts & Bakery
# Name: Glazed Donut
# Description: Classic yeast donut coated in vanilla glaze
# Long Description: Soft, airy donut finished with a signature sweet glaze. Pair it with hot coffee for the quintessential Dunkin duo.
# Origin: Dunkin Bakery
# Caffeine Content:
# Brewing Method:
# Popularity: Iconic
# Sizes: [{"size": "standard", "price": 1.49}]
# Embedding: [-0.020710768178105354, -0.010922630317509174, -0.017597220838069916, 0.029748883098363876, -0.017017370089888573, 0.024202480912208557, 0.030505210161209106, -0.02035781554877758, -0.007191414013504982, -0.017206450924277306]...
#
# ID: donuts___bakery_boston_kreme_donut
# Category: Donuts & Bakery
# Name: Boston Kreme Donut
# Description: Custard-filled donut topped with chocolate icing
# Long Description: A nod to Dunkin's New England roots featuring silky Bavarian cream and rich chocolate icing.
# Origin: Boston, MA
# Caffeine Content:
# Brewing Method:
# Popularity: Regional Favorite
# Sizes: [{"size": "standard", "price": 1.79}]
# Embedding: [-0.006009567528963089, -0.025421224534511566, -0.02092033438384533, 0.014370158314704895, -0.014935912564396858, 0.015539383515715599, 0.003598825540393591, -0.014697038568556309, -0.025119489058852196, 0.028237422928214073]...
#
# ID: donuts___bakery_everything_bagel___cream_cheese
# Category: Donuts & Bakery
# Name: Everything Bagel & Cream Cheese
# Description: Toasted everything bagel with plain cream cheese
# Long Description: Freshly toasted bagel coated with sesame, poppy seeds, garlic, and onion, served with cool cream cheese spread.
# Origin: Dunkin Bakery
# Caffeine Content:
# Brewing Method:
# Popularity: Morning Rush MVP
# Sizes: [{"size": "standard", "price": 3.29}]
# Embedding: [-0.045473624020814896, -0.015895074233412743, -0.02183147892355919, -0.0011882506078109145, -0.017524676397442818, 0.012849273160099983, 0.016321875154972076, -0.015080275014042854, -0.0187145434319973, -0.007494870573282242]...
#
# ID: donuts___bakery_munchkins___donut_hole_treats__10_ct_
# Category: Donuts & Bakery
# Name: MUNCHKINSÂ® Donut Hole Treats (10 ct)
# Description: Assorted bite-sized donuts
# Long Description: Shareable assortment of glazed, chocolate, and jelly MUNCHKINS donut holesâ€”perfect for offices and carpool lines.
# Origin: Dunkin Bakery
# Caffeine Content:
# Brewing Method:
# Popularity: Group Favorite
# Sizes: [{"size": "standard", "price": 3.99}]
# Embedding: [-0.03847699612379074, -0.0227169468998909, -0.02410832606256008, 0.0019666615407913923, -0.01542558241635561, 0.03160037100315094, 0.00901052076369524, -0.015144631266593933, -0.010207909159362316, 0.037968605756759644]...
#
# ID: breakfast_sandwiches_bacon_egg___cheese_on_croissant
# Category: Breakfast Sandwiches
# Name: Bacon Egg & Cheese on Croissant
# Description: Cherrywood smoked bacon, eggs, and American cheese
# Long Description: A flaky croissant stacked with cherrywood smoked bacon, fluffy eggs, and melty cheese to fuel busy mornings.
# Origin: Dunkin Kitchens
# Caffeine Content:
# Brewing Method:
# Popularity: Top Seller
# Sizes: [{"size": "standard", "price": 4.99}]
# Embedding: [-0.012097797356545925, -0.022920168936252594, -0.021194590255618095, 0.005170479882508516, -0.0022585680708289146, 0.027559220790863037, 0.013467005454003811, -0.030735282227396965, -0.012222839519381523, 0.004879757761955261]...
#
# ID: breakfast_sandwiches_power_breakfast_sandwich
# Category: Breakfast Sandwiches
# Name: Power Breakfast Sandwich
# Description: Multi-grain bread with turkey sausage and egg whites
# Long Description: Better-for-you build with veggie egg white omelet, turkey sausage, and aged white cheddar on seeded multigrain bread.
# Origin: Inspire Brands Nutrition Lab
# Caffeine Content:
# Brewing Method:
# Popularity: Balanced Choice
# Sizes: [{"size": "standard", "price": 5.49}]
# Embedding: [0.0074998424388468266, 0.000644517713226378, -0.02030542492866516, 0.04061084985733032, 0.022193683311343193, 0.03614285960793495, 0.04380227252840996, -0.031089773401618004, 0.027206875383853912, 0.00845062080770731]...
#
# ID: breakfast_sandwiches_turkey_sausage_wake-up_wrap
# Category: Breakfast Sandwiches
# Name: Turkey Sausage Wake-Up Wrap
# Description: Egg and turkey sausage in a warm tortilla
# Long Description: Portable protein with scrambled egg, turkey sausage, and American cheese inside a grilled tortilla.
# Origin: Dunkin Anytime Menu
# Caffeine Content:
# Brewing Method:
# Popularity: Value Leader
# Sizes: [{"size": "standard", "price": 2.59}]
# Embedding: [-0.014398759230971336, 0.006652174051851034, -0.012928556650876999, 0.04113931208848953, 0.0029865559190511703, 0.03001060150563717, 0.04715198278427124, -0.03156651183962822, -0.008049855940043926, -0.004077670630067587]...
#
# ID: extras_flavor_swirl_add-on
# Category: Extras
# Name: Flavor Swirl Add-On
# Description: Caramel, mocha, French vanilla, or seasonal swirl
# Long Description: Rich, creamy swirls that add sweetness and color to any hot or iced beverage.
# Origin:
# Caffeine Content:
# Brewing Method:
# Popularity:
# Sizes: [{"size": "standard", "price": 0.75}]
# Embedding: [-0.020891396328806877, -0.020640699192881584, -0.025069676339626312, 0.02261841855943203, -0.02515324205160141, 0.022075243294239044, -0.029275810346007347, -0.023997250944375992, -0.03896941989660263, 0.001451081596314907]...
#
# ID: extras_whipped_cream
# Category: Extras
# Name: Whipped Cream
# Description: Add whipped cream topping
# Long Description: Finish drinks with house-made whipped cream for extra texture and presentation.
# Origin:
# Caffeine Content:
# Brewing Method:
# Popularity:
# Sizes: [{"size": "standard", "price": 0.5}]
# Embedding: [-0.03243148699402809, -0.03243148699402809, -0.027113940566778183, 0.01564798504114151, -0.00946495309472084, -0.022668804973363876, -0.0013562163803726435, -0.00884872768074274, -0.01762821525335312, 0.028831064701080322]...
#
# ID: extras_extra_espresso_shot
# Category: Extras
# Name: Extra Espresso Shot
# Description: Add one additional espresso shot
# Long Description: Boost any beverage with a fresh-pulled Dunkin espresso shot for added intensity.
# Origin:
# Caffeine Content: 75 mg per shot
# Brewing Method:
# Popularity:
# Sizes: [{"size": "standard", "price": 1.0}]
# Embedding: [-0.011268533766269684, -0.017334047704935074, -0.01795111782848835, 0.010707561857998371, 0.01834379881620407, -0.012586819007992744, 0.015566985122859478, 0.03671564534306526, -0.03127421438694, 0.0012884836178272963]...

# %% [markdown]
# ## 8: Upload to Azure AI Search
#
# ### Description
# This cell defines and calls a function to upload the prepared data to Azure AI Search.
# Ensure the Azure AI Search index is properly configured before running this step.

# %%
def upload_documents_to_search(documents):
    batch_size = 15
    total_batches = (len(documents) + batch_size - 1) // batch_size  # Calculate total number of batches
    successful_uploads = 0

    for i in range(0, len(documents), batch_size):
        batch = documents[i:i + batch_size]
        try:
            # Upload the batch
            response = search_client.upload_documents(documents=batch)
            successful_uploads += len(batch)
            print(f"Uploaded batch {i // batch_size + 1}/{total_batches} successfully. Batch size: {len(batch)}")
        except HttpResponseError as e:
            print(f"Error uploading batch {i // batch_size + 1}/{total_batches}: {e}")
            # Log the problematic batch for further inspection
            # print(f"Problematic batch: {batch}")
            continue

    print(f"Embedding index created and documents uploaded successfully. Total successful uploads: {successful_uploads}/{len(documents)}")

upload_documents_to_search(documents_for_index)
# Out:
# Uploaded batch 1/2 successfully. Batch size: 15
# Uploaded batch 2/2 successfully. Batch size: 1
# Embedding index created and documents uploaded successfully. Total successful uploads: 16/16

# %% [markdown]
# ## 9: Testing Search Capabilities
#
# ### Summary
# - Upgraded the Azure Search Documents package for compatibility.
# - Defined four search function implementations:
#   - Simple text-based search
#   - Semantic search using the configured semantic configuration
#   - Vector search using embeddings for semantic similarity
#   - Hybrid search combining text and vector capabilities
# - Tested each search type with different queries:
#   - Simple search for "espresso"
#   - Semantic search for "coffee with chocolate flavors"
#   - Vector search for "strong coffee with intense flavor"
#   - Hybrid search for "smooth coffee from not Italy"
#   - Filter-based search for coffee in the "Brewed Coffee" category from Italy
# - Each search function formats and displays results with relevant coffee item details.

# %%
# Test Azure AI Search with various query types
# %pip install --upgrade azure-search-documents
from azure.search.documents.models import VectorizedQuery


def perform_simple_search(query_text, filter_condition=None, top=5):
    """Perform a simple text-based search against the Azure Search index"""
    results = search_client.search(
        search_text=query_text,
        filter=filter_condition,
        select=["id", "name", "description", "category", "origin"],
        top=top,
        include_total_count=True
    )

    print(f"\n=== Simple Search Results for '{query_text}' ===")
    print(f"Total matches: {results.get_count()}")

    for result in results:
        print(f"\nName: {result['name']}")
        print(f"Category: {result['category']}")
        print(f"Origin: {result.get('origin', 'Not specified')}")
        print(f"Description: {result['description']}")
        print("-" * 50)

    return results


def perform_semantic_search(query_text, top=5):
    """Perform a semantic search using the configured semantic settings"""
    try:
        results = search_client.search(
            search_text=query_text,
            select=["id", "name", "description", "category", "origin"],
            top=top,
            query_type="semantic",
            semantic_configuration_name="menuSemanticConfig",
            include_total_count=True
        )
    except HttpResponseError as e:
        print("Semantic search is not enabled for this search service or request. Enable semantic search in the Azure portal or use simple search instead.")
        print(f"Details: {e}")
        return None

    print(f"\n=== Semantic Search Results for '{query_text}' ===")
    print(f"Total matches: {results.get_count()}")

    for result in results:
        print(f"\nName: {result['name']}")
        print(f"Category: {result['category']}")
        print(f"Origin: {result.get('origin', 'Not specified')}")
        print(f"Description: {result['description']}")
        print("-" * 50)

    return results


def perform_vector_search(query_text, top=5):
    """Generate embedding for the query and perform vector search"""
    from openai import AzureOpenAI

    # Create Azure OpenAI client for embeddings
    client = AzureOpenAI(
        api_key=aoai_eastus_api_key,
        api_version="2023-05-15",
        azure_endpoint=aoai_eastus_endpoint
    )

    # Generate embedding for the query text
    response = client.embeddings.create(
        input=query_text,
        model=aoai_embedding_deployment
    )

    query_vector = response.data[0].embedding

    # Perform vector search - fixed to use vector_queries instead of vector
    vector_query = VectorizedQuery(vector=query_vector, k_nearest_neighbors=top, fields="embedding")
    results = search_client.search(
        search_text=None,
        select=["id", "name", "description", "category", "origin"],
        top=top,
        vector_queries=[vector_query],
        include_total_count=True
    )

    print(f"\n=== Vector Search Results for '{query_text}' ===")
    print(f"Total matches: {results.get_count()}")

    for result in results:
        print(f"\nName: {result['name']}")
        print(f"Category: {result['category']}")
        print(f"Origin: {result.get('origin', 'Not specified')}")
        print(f"Description: {result['description']}")
        print("-" * 50)

    return results


def perform_hybrid_search(query_text, top=5):
    """Perform a hybrid search combining vector search with text search"""
    from openai import AzureOpenAI

    # Create Azure OpenAI client for embeddings
    client = AzureOpenAI(
        api_key=aoai_eastus_api_key,
        api_version="2023-05-15",
        azure_endpoint=aoai_eastus_endpoint
    )

    # Generate embedding for the query text
    response = client.embeddings.create(
        input=query_text,
        model=aoai_embedding_deployment
    )

    query_vector = response.data[0].embedding

    # Perform hybrid search - fixed to use vector_queries instead of vector
    vector_query = VectorizedQuery(vector=query_vector, k_nearest_neighbors=top, fields="embedding")
    results = search_client.search(
        search_text=query_text,
        select=["id", "name", "description", "category", "origin"],
        top=top,
        vector_queries=[vector_query],
        include_total_count=True
    )

    print(f"\n=== Hybrid Search Results for '{query_text}' ===")
    print(f"Total matches: {results.get_count()}")

    for result in results:
        print(f"\nName: {result['name']}")
        print(f"Category: {result['category']}")
        print(f"Origin: {result.get('origin', 'Not specified')}")
        print(f"Description: {result['description']}")
        print("-" * 50)

    return results


# Test different search types
print("\n========= TESTING SEARCH CAPABILITIES =========")

# Test 1: Simple text search
simple_results = perform_simple_search("espresso")

# Test 2: Semantic search for more natural language queries
semantic_results = perform_semantic_search("coffee with chocolate flavors")

# Test 3: Vector search for semantic similarity
vector_results = perform_vector_search("strong coffee with intense flavor")

# Test 4: Hybrid search combining text and vector capabilities
hybrid_results = perform_hybrid_search("smooth coffee from not Italy")

# Test 5: Search with filters
filtered_results = perform_simple_search(
    "coffee", 
    filter_condition="category eq 'Brewed Coffee' and origin eq 'Italy'"
)
# Out:
# Requirement already satisfied: azure-search-documents in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (11.6.0)
# Requirement already satisfied: azure-core>=1.28.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from azure-search-documents) (1.36.0)
# Requirement already satisfied: azure-common>=1.1 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from azure-search-documents) (1.1.28)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from azure-search-documents) (0.7.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from azure-search-documents) (4.15.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from azure-core>=1.28.0->azure-search-documents) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-search-documents) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-search-documents) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-search-documents) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\brswig\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-search-documents) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.
#
# ========= TESTING SEARCH CAPABILITIES =========
#
# === Simple Search Results for 'espresso' ===
# Total matches: 4
#
# Name: Extra Espresso Shot
# Category: Extras
# Origin:
# Description: Add one additional espresso shot
# --------------------------------------------------
#
# Name: Caramel Craze Latte
# Category: Signature Lattes
# Origin: Dunkin U.S. Menu
# Description: Espresso with caramel drizzle and whipped cream
# --------------------------------------------------
#
# Name: Toasted Almond Cold Foam Latte
# Category: Signature Lattes
# Origin: Dunkin Next-Gen Restaurant
# Description: Iced latte with toasted almond swirl and cold foam cap
# --------------------------------------------------
#
# Name: Cocoa Mocha Latte
# Category: Signature Lattes
# Origin: Inspire Brands Innovation Lab
# Description: Chocolate-forward espresso drink finished with mocha drizzle
# --------------------------------------------------
#
# === Semantic Search Results for 'coffee with chocolate flavors' ===
# Total matches: 4
#
# Name: Extra Espresso Shot
# Category: Extras
# Origin:
# Description: Add one additional espresso shot
# --------------------------------------------------
#
# Name: Caramel Craze Latte
# Category: Signature Lattes
# Origin: Dunkin U.S. Menu
# Description: Espresso with caramel drizzle and whipped cream
# --------------------------------------------------
#
# Name: Toasted Almond Cold Foam Latte
# Category: Signature Lattes
# Origin: Dunkin Next-Gen Restaurant
# Description: Iced latte with toasted almond swirl and cold foam cap
# --------------------------------------------------
#
# Name: Cocoa Mocha Latte
# Category: Signature Lattes
# Origin: Inspire Brands Innovation Lab
# Description: Chocolate-forward espresso drink finished with mocha drizzle
# --------------------------------------------------
#
# === Semantic Search Results for 'coffee with chocolate flavors' ===
# Total matches: 14
# Total matches: 14
#
# Name: Cocoa Mocha Latte
# Category: Signature Lattes
# Origin: Inspire Brands Innovation Lab
# Description: Chocolate-forward espresso drink finished with mocha drizzle
# --------------------------------------------------
#
# Name: Glazed Donut
# Category: Donuts & Bakery
# Origin: Dunkin Bakery
# Description: Classic yeast donut coated in vanilla glaze
# --------------------------------------------------
#
# Name: Extra Espresso Shot
# Category: Extras
# Origin:
# Description: Add one additional espresso shot
# --------------------------------------------------
#
# Name: Caramel Craze Latte
# Category: Signature Lattes
# Origin: Dunkin U.S. Menu
# Description: Espresso with caramel drizzle and whipped cream
# --------------------------------------------------
#
# Name: Brown Sugar Cream Cold Brew
# Category: Cold Beverages
# Origin: Inspire Brands Test Kitchen
# Description: Cold brew with brown sugar syrup and cinnamon-sugar cold foam
# --------------------------------------------------
#
# Name: Cocoa Mocha Latte
# Category: Signature Lattes
# Origin: Inspire Brands Innovation Lab
# Description: Chocolate-forward espresso drink finished with mocha drizzle
# --------------------------------------------------
#
# Name: Glazed Donut
# Category: Donuts & Bakery
# Origin: Dunkin Bakery
# Description: Classic yeast donut coated in vanilla glaze
# --------------------------------------------------
#
# Name: Extra Espresso Shot
# Category: Extras
# Origin:
# Description: Add one additional espresso shot
# --------------------------------------------------
#
# Name: Caramel Craze Latte
# Category: Signature Lattes
# Origin: Dunkin U.S. Menu
# Description: Espresso with caramel drizzle and whipped cream
# --------------------------------------------------
#
# Name: Brown Sugar Cream Cold Brew
# Category: Cold Beverages
# Origin: Inspire Brands Test Kitchen
# Description: Cold brew with brown sugar syrup and cinnamon-sugar cold foam
# --------------------------------------------------
#
# === Vector Search Results for 'strong coffee with intense flavor' ===
#
# === Vector Search Results for 'strong coffee with intense flavor' ===
# Total matches: 5
# Total matches: 5
#
# Name: Original Cold Brew
# Category: Cold Beverages
# Origin: Dunkin Breweries
# Description: 12-hour steeped cold brew over ice
# --------------------------------------------------
#
# Name: Extra Espresso Shot
# Category: Extras
# Origin:
# Description: Add one additional espresso shot
# --------------------------------------------------
#
# Name: Brown Sugar Cream Cold Brew
# Category: Cold Beverages
# Origin: Inspire Brands Test Kitchen
# Description: Cold brew with brown sugar syrup and cinnamon-sugar cold foam
# --------------------------------------------------
#
# Name: Cocoa Mocha Latte
# Category: Signature Lattes
# Origin: Inspire Brands Innovation Lab
# Description: Chocolate-forward espresso drink finished with mocha drizzle
# --------------------------------------------------
#
# Name: Caramel Craze Latte
# Category: Signature Lattes
# Origin: Dunkin U.S. Menu
# Description: Espresso with caramel drizzle and whipped cream
# --------------------------------------------------
#
# Name: Original Cold Brew
# Category: Cold Beverages
# Origin: Dunkin Breweries
# Description: 12-hour steeped cold brew over ice
# --------------------------------------------------
#
# Name: Extra Espresso Shot
# Category: Extras
# Origin:
# Description: Add one additional espresso shot
# --------------------------------------------------
#
# Name: Brown Sugar Cream Cold Brew
# Category: Cold Beverages
# Origin: Inspire Brands Test Kitchen
# Description: Cold brew with brown sugar syrup and cinnamon-sugar cold foam
# --------------------------------------------------
#
# Name: Cocoa Mocha Latte
# Category: Signature Lattes
# Origin: Inspire Brands Innovation Lab
# Description: Chocolate-forward espresso drink finished with mocha drizzle
# --------------------------------------------------
#
# Name: Caramel Craze Latte
# Category: Signature Lattes
# Origin: Dunkin U.S. Menu
# Description: Espresso with caramel drizzle and whipped cream
# --------------------------------------------------
#
# === Hybrid Search Results for 'smooth coffee from not Italy' ===
#
# === Hybrid Search Results for 'smooth coffee from not Italy' ===
# Total matches: 6
# Total matches: 6
#
# Name: Original Cold Brew
# Category: Cold Beverages
# Origin: Dunkin Breweries
# Description: 12-hour steeped cold brew over ice
# --------------------------------------------------
#
# Name: Cocoa Mocha Latte
# Category: Signature Lattes
# Origin: Inspire Brands Innovation Lab
# Description: Chocolate-forward espresso drink finished with mocha drizzle
# --------------------------------------------------
#
# Name: Glazed Donut
# Category: Donuts & Bakery
# Origin: Dunkin Bakery
# Description: Classic yeast donut coated in vanilla glaze
# --------------------------------------------------
#
# Name: Brown Sugar Cream Cold Brew
# Category: Cold Beverages
# Origin: Inspire Brands Test Kitchen
# Description: Cold brew with brown sugar syrup and cinnamon-sugar cold foam
# --------------------------------------------------
#
# Name: Toasted Almond Cold Foam Latte
# Category: Signature Lattes
# Origin: Dunkin Next-Gen Restaurant
# Description: Iced latte with toasted almond swirl and cold foam cap
# --------------------------------------------------
#
# === Simple Search Results for 'coffee' ===
#
# Name: Original Cold Brew
# Category: Cold Beverages
# Origin: Dunkin Breweries
# Description: 12-hour steeped cold brew over ice
# --------------------------------------------------
#
# Name: Cocoa Mocha Latte
# Category: Signature Lattes
# Origin: Inspire Brands Innovation Lab
# Description: Chocolate-forward espresso drink finished with mocha drizzle
# --------------------------------------------------
#
# Name: Glazed Donut
# Category: Donuts & Bakery
# Origin: Dunkin Bakery
# Description: Classic yeast donut coated in vanilla glaze
# --------------------------------------------------
#
# Name: Brown Sugar Cream Cold Brew
# Category: Cold Beverages
# Origin: Inspire Brands Test Kitchen
# Description: Cold brew with brown sugar syrup and cinnamon-sugar cold foam
# --------------------------------------------------
#
# Name: Toasted Almond Cold Foam Latte
# Category: Signature Lattes
# Origin: Dunkin Next-Gen Restaurant
# Description: Iced latte with toasted almond swirl and cold foam cap
# --------------------------------------------------
#
# === Simple Search Results for 'coffee' ===
# Total matches: 0
# Total matches: 0

# %% [markdown]
# ## 10: Final Summary
#
# ### Summary
# - Installed required packages.
# - Configured Azure OpenAI and Azure AI Search services.
# - Defined and created/updated the index schema with semantic configuration.
# - Loaded and processed menu data from `menuItems.json`.
# - Prepared data for ingestion, including generating embeddings using Azure OpenAI.
# - Uploaded the structured data into Azure AI Search.
#
# The pipeline is now complete!
